# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
from cryptography.hazmat.primitives.ciphers import (
    Cipher, algorithms, modes
)
from cryptography.hazmat.primitives.asymmetric import rsa , padding , utils
from cryptography.hazmat.primitives import serialization , hashes
from cryptography.hazmat.backends import default_backend

# %% [markdown]
# # Helper functions

# %%
def show_pic(img):
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    fig = plt.figure(figsize=(15,15))
    ax = fig.add_subplot(111)
    ax.imshow(img)
#     plt.title(name)

# %%
def load_img(imgPath):
    img = cv2.imread(imgPath)
#     img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    return img

# %%
def load_show_img(imgPath):
    img = load_img(imgPath)
    show_pic(img)
    return img

# %%
def read_file(fileName):
    file = open(fileName, "r")
    message = file.read()
    file.close()
    return message

# %%
def write_file(fileName, message):
    file = open(fileName, "w")
    file.write(message)
    file.close()

# %%
def write_pem(pem, filePath):
    file = open(filePath, "wb")
    file.write(pem)
    file.close()

# %% [markdown]
# # Helper functions to convert data to binary

# %%
def pixel2binary(pixel):
    
  if type(pixel) == bytes or type(pixel) == np.ndarray:
    result= [ format(i, "08b") for i in pixel ]
    
  else:
    raise TypeError("Input type is not supported")
    
  return result

# %%
def cipher2binary(message):
    
  if type(message) == bytes:
    result= ''.join([ format(i, "08b") for i in message ])

  else:
    raise TypeError("Input type is not supported")
    
  return result

# %% [markdown]
# # Steganography encoder & decoder functions

# %%
def encode_data_to_img(imgFileName, data):
    
    list1=[ ]
    
    if (len(data) == 0): 
      raise ValueError('Data is empty')
  
#     filename = input("Enter the name of the New Image after Encoding(without extension):")
#     filename += '.png'
    
    img = load_img(imgFileName)
    no_bytes=(img.shape[0] * img.shape[1] * 3) // 8
    
    print("Maximum bytes to encode:", no_bytes-3)
    
    
#     # Using the below as delimeter
    delim = b'***'
    data+=delim
    
    if(len(data)>no_bytes):
        raise ValueError("Error encountered Insufficient bytes, Need Bigger Image or give Less Data !!")
        
    data_binary= cipher2binary(data)
    print(data_binary)
    
    #number of bits
    data_len=len(data_binary)
    
    print("The Length of Binary data",data_len)
    
    data_index = 0
    
    for row in img:
        for pixel in row:
          r, g, b = pixel2binary(pixel)

          if data_index < data_len:
              # hiding the data into LSB(Least Significant Bit) of Red Pixel
              pixel[0] = int(r[:-1] + data_binary[data_index], 2) #changing to binary after overwrriting the LSB bit of Red Pixel
              data_index += 1
              list1.append(pixel[0])

          if data_index < data_len:
             # hiding the data into LSB of Green Pixel
              pixel[1] = int(g[:-1] + data_binary[data_index], 2) #changing to binary after overwrriting the LSB bit of Green Pixel
              data_index += 1
              list1.append(pixel[1])

          if data_index < data_len:
              # hiding the data into LSB of  Blue Pixel
              pixel[2] = int(b[:-1] + data_binary[data_index], 2) #changing to binary after overwrriting the LSB bit of Blue pixel
              data_index += 1
              list1.append(pixel[2])

              # if data is encoded, just breaking out of the Loop
          if data_index >= data_len:
              break
    
    encryptedImgName = 'encryption/encrypted.png'
    cv2.imwrite(encryptedImgName,img)
    
    print("Encoded the data successfully and the image is successfully saved as ",encryptedImgName)
    return encryptedImgName

# %%
def decode_data_from_img(imgFileName):

  img = load_img(imgFileName)
  finished = False
  counter = 0
  binary_data = ''
  decoded_data = b''
  pixels_count = (img.shape[0] * img.shape[1] * 3)
  
  for row in img:
      for pixel in row:
        
          r, g, b = pixel2binary(pixel) 
          binary_data += r[-1]  #Extracting Encoded data from the LSB bit of Red Pixel as we have stored in LSB bit of every pixel.
          binary_data += g[-1]  #Extracting Encoded data from the LSB bit of Green Pixel
          binary_data += b[-1]  #Extracting Encoded data from LSB bit of Blue Pixel
          counter += 3
          
          # last 3 bytes
          if(counter%24 == 0) or counter == pixels_count:
              # splitting last 3 bytes by 8-bits
              last3bytes = [ binary_data[i: i+8] for i in range(0, len(binary_data), 8) ]
#               print(last3bytes)
              for byte in last3bytes:
                  b = int(byte, 2).to_bytes((len(byte) + 7) // 8, 'big')
                  decoded_data += b
                  if decoded_data[-3:] == b"***": #Checking if we have reached the delimeter which is "*****"
                      finished = True
                      break
                    
              binary_data = ""
              last3bytes = []
          if finished:
              break
      if finished:
        break
                
  print("The Encoded data was :--",decoded_data[:-3])
  return decoded_data[:-3]

# %% [markdown]
# # AES encryption and decryption functions

# %%
def encrypt_AES(key, iv, plaintext):
    # Construct an AES-GCM Cipher object with the given key and a
    # randomly generated IV.
    encryptor = Cipher(
        algorithms.AES(key),
        modes.GCM(iv),
    ).encryptor()


    # Encrypt the plaintext and get the associated ciphertext.
    # GCM does not require padding.
    ciphertext = encryptor.update(plaintext)

    return ciphertext

def decrypt_AES(key, iv, ciphertext):
    # Construct a Cipher object, with the key, iv, and additionally the
    # GCM tag used for authenticating the message.
    decryptor = Cipher(
        algorithms.AES(key),
        modes.GCM(iv),
    ).decryptor()


    # Decryption gets us the authenticated plaintext.
    # If the tag does not match an InvalidTag exception will be raised.
    return decryptor.update(ciphertext)

# %% [markdown]
# # AES with steganography Driver Function

# %%
def AES_encrypt_and_encode(imgFileName, textFileName, key):
    iv = b'd\xfe\xb7\x9a\xee\xd6\xa7\xb2\x0c\xf65\x16'
    message = read_file(textFileName)
    ciphertext = encrypt_AES(key,iv , message.encode('utf-8'))
    
    encryptedImgPath = encode_data_to_img(imgFileName, ciphertext)
    
    print("Original Message: ", message)
    print("Ciphertext: ", ciphertext)
    
    load_show_img(encryptedImgPath)
    
    return encryptedImgPath
    

def AES_decode_and_decrypt(imgPath, restoredFileName, key):
    iv = b'd\xfe\xb7\x9a\xee\xd6\xa7\xb2\x0c\xf65\x16'
    ciphertext = decode_data_from_img(imgPath)
    message = decrypt_AES(key, iv, ciphertext)
    originalMessage = message.decode('utf-8')
    
    print("Ciphertext: ", ciphertext)
    print("Original Message: ", originalMessage)
    
    write_file(restoredFileName, originalMessage)
    
    return originalMessage

# %% [markdown]
# # RSA private and public key functions

# %%
# Create private key
def Create_private_key():
    private_key = rsa.generate_private_key(
        public_exponent=65537,
        key_size=2048,
        backend=default_backend()
    )
    return private_key

# Create public key
def Create_public_key(private_key):
    public_key = private_key.public_key()
    return public_key

def read_public_pem(filePath):
    with open(filePath, "rb") as key_file:

        public_key = serialization.load_pem_public_key(

            key_file.read(),
        )

    return public_key

def read_private_pem(filePath):
    with open(filePath, "rb") as key_file:

        private_key = serialization.load_pem_private_key(

            key_file.read(),

            password=None,

        )

    return private_key

def generate_key_pem():
    private_key = Create_private_key()
    public_key = Create_public_key(private_key)
    
    private_pem = private_key.private_bytes(

       encoding=serialization.Encoding.PEM,

       format=serialization.PrivateFormat.TraditionalOpenSSL,

       encryption_algorithm=serialization.NoEncryption()

    )
    
    public_pem = public_key.public_bytes(

       encoding=serialization.Encoding.PEM,

       format=serialization.PublicFormat.SubjectPublicKeyInfo

    )
    write_pem(private_pem, "content/private_key.pem")
    write_pem(public_pem, "content/public_key.pem")

# %% [markdown]
# # RSA encrypt and decrypt functions

# %%
#RSA
#encrypt take a plaintext as a bytes like AES -->(utf-8)
#return a ciphertext as bytes -->(utf-8)
def encrypt_RSA(public_key, plaintext):
    ciphertext = public_key.encrypt(
        plaintext,
        padding.OAEP(
            mgf=padding.MGF1(algorithm=hashes.SHA1()),
            algorithm=hashes.SHA1(),
            label=None
        )
    )

    return ciphertext

#decrypt take a ciphertext as a bytes like AES -->(utf-8)
#return a plaintext as bytes -->(utf-8)
def decrypt_RSA(private_key, ciphertext):
    plaintext = private_key.decrypt(
        ciphertext,
        padding.OAEP(
            mgf=padding.MGF1(algorithm=hashes.SHA1()),
            algorithm=hashes.SHA1(),
            label=None
        )
    )

    return plaintext

# %% [markdown]
# # RSA with steganography Driver Function

# %%
def RSA_encrypt_and_encode(imgFileName, textFileName,publicKeyPath):
    public_key = read_public_pem(publicKeyPath)
    print(textFileName)
    message = read_file(textFileName)
    ciphertext = encrypt_RSA(public_key, message.encode("utf-8"))
    
    encryptedImgPath = encode_data_to_img(imgFileName, ciphertext)
    
    print("Original Message: ", message)
    print("Ciphertext: ", ciphertext)
    
    load_show_img(encryptedImgPath)
    
    return encryptedImgPath
    

def RSA_decode_and_decrypt(imgPath, restoredFileName , privateKeyPath):
    private_key = read_private_pem(privateKeyPath)
    ciphertext = decode_data_from_img(imgPath)
    message = decrypt_RSA(private_key, ciphertext)
    originalMessage = message.decode('utf-8')
    
    print("Ciphertext: ", ciphertext)
    print("Original Message: ", originalMessage)
    
    write_file(restoredFileName, originalMessage)
    
    return originalMessage

# %% [markdown]
# # Generating public and private keys pem for RSA

# %%
generate_key_pem()

# %% [markdown]
# # GUI

# %%
#Import tkinter library
from tkinter import *
from tkinter.filedialog import askopenfilename 
from tkinter import scrolledtext

# All screen size
window_width,window_height = 600,400

##########
# AES UI #
##########
def AES_upload_original_image_file():
    filename = askopenfilename()
    global original_image_path
    original_image_path=Text(AES_encrpt_input,width=50,height=3)
    original_image_path.place(x = 180 , y = 80)
    original_image_path.insert(END, filename)
    
    
def AES_upload_message_file():
    filename = askopenfilename()
    global messagePath_text
    messagePath_text=Text(AES_encrpt_input,width=50,height=3)
    messagePath_text.place(x = 180 , y = 150)
    messagePath_text.insert(END, filename)
    
def AES_upload_restored_file():
    filename = askopenfilename()
    global messagePath_text
    messagePath_text= Text(AES_decrypt_input,width=50,height=3)
    messagePath_text.place(x = 180 , y = 150)
    messagePath_text.insert(INSERT, filename)
    
def AES_encrypt_submit():
    global imageFileName
    global key_test
    global textFileName
    key_test = key_text_field.get("1.0","end")
    imageFileName = original_image_path.get("1.0","end")
    textFileName = messagePath_text.get("1.0","end")
    
    
def AES_Get_encrypt_ImagePath():
    filename = askopenfilename()
    global original_image_path
    original_image_path = Text(AES_decrypt_input,width=50,height=3)
    original_image_path.place(x = 180 , y = 80)
    original_image_path.insert(INSERT, filename)

def Home_screen() :
    global Home
    Home= Tk()
    Home.title("Security Project")
    Home.configure(background = '#222b45')
    #Set the geometry of tkinter frame
    screen_width = Home.winfo_screenwidth()
    screen_height = Home.winfo_screenheight()
    
    position_top = int(screen_height/2 - window_height/2)
    position_right = int(screen_width/2 - window_width/2)
    
    Home.geometry(f'{window_width}x{window_height}+{position_right}+{position_top}')
    
    Label(Home, text="Select Cryptography Algorithms", font=('Century 20 bold'),bg= '#222b45', fg=('white')).place(x = 80 , y = 80)
    #Create a Label and a Button widget
    btn1=Button(Home, text="AES", width=15, height=2 ,font=10,bg=("#51B5D4"), 
                fg=('white'),command=AES_en_de).place(x = 120 , y = 200)
    btn2=Button(Home, text="RSA", width=15, height=2 ,font=10,bg=("#51B5D4"), 
                fg=('white'),command=RSA_en_de).place(x = 310 , y = 200)
    Home.mainloop()

#-----------------------------------------------------------------------------------------------------

def AES_en_de():
    Home.destroy()
    global win1
    win1 =Tk()
    win1.title("Security Project")
    win1.configure(background = '#222b45')
    screen_width = win1.winfo_screenwidth()
    screen_height = win1.winfo_screenheight()
    
    position_top = int(screen_height/2 - window_height/2)
    position_right = int(screen_width/2 - window_width/2)
    
    win1.geometry(f'{window_width}x{window_height}+{position_right}+{position_top}')
    
    L1 =Label (win1, text='AES  Encrypt  or  Decrypt',font=(60),bg= '#222b45', fg=('white'))
    L1.pack(pady=100)   
    B1 = Button (win1, text='Encrypt', width=15, height=2 ,font=10,bg=("#51B5D4"), fg=('white'),
                command=AES_encrpt_input_screen).place(x=100,y=215)
    B2 = Button (win1, text='Decrypt', width=15, height=2 ,font=10,bg=("#51B5D4"), fg=('white'),
                 command=AES_decrypt_input_screen).place(x=350,y=215)
    win1.mainloop()

#--------------------------------------------------------------------------------------------------------------

def RSA_en_de():
    Home.destroy()
    global win2
    win2 =Tk()
    win2.title("Security Project")
    win2.configure(background = '#222b45')
    screen_width = win2.winfo_screenwidth()
    screen_height = win2.winfo_screenheight()
    
    position_top = int(screen_height/2 - window_height/2)
    position_right = int(screen_width/2 - window_width/2)
    
    win2.geometry(f'{window_width}x{window_height}+{position_right}+{position_top}')
    
    L1 =Label (win2, text='RSA  Encrypt  or  Decrypt',font=(60),bg= '#222b45',fg=('white'))
    L1.pack(pady=100)   
    B1 = Button (win2, text='Encrypt', width=15, height=2 ,font=10,bg=("#51B5D4"), fg=('white'),
                command=RSA_encrpt_input_screen).place(x=100,y=215)
    B2 = Button (win2, text='Decrypt', width=15, height=2 ,font=10,bg=("#51B5D4"), fg=('white'),
                 command=RSA_decrypt_input_screen).place(x=350,y=215)
    win2.mainloop()

#------------------------------------------------------------------------------------------------------------

def AES_encrpt_input_screen() :
    win1.destroy()
    global AES_encrpt_input
    AES_encrpt_input = Tk()
    AES_encrpt_input.title("Security Project")
    AES_encrpt_input.configure(background = '#222b45')
    screen_width = AES_encrpt_input.winfo_screenwidth()
    screen_height = AES_encrpt_input.winfo_screenheight()
    
    position_top = int(screen_height/2 - window_height/2)
    position_right = int(screen_width/2 - window_width/2)
    
    AES_encrpt_input.geometry(f'{window_width}x{window_height}+{position_right}+{position_top}')
    
    Label(AES_encrpt_input, text="AES encrpt input",width=15,height=2, 
          font=('content/entury 20 bold',15),bg= '#222b45',fg=('white')).place(x = 200 , y = 20)
    
    # Image Path
    Label(AES_encrpt_input, text="Image path",width=15,height=2, 
          font=('content/entury 20 bold',12),bg= '#222b45', fg=('white')).place(x = 10 , y = 80)
    global original_image_path
    original_image_path = Text(AES_encrpt_input,width=50,height=3)
    original_image_path.place(x = 180 , y = 80)
    image_path_button = Button(AES_encrpt_input, text="...", width=2,height=2 ,
                                font=('Century 20 bold',5),bg=('lightgray'), 
                                fg=('white'),command=AES_upload_original_image_file).place(x = 150 , y = 90)
    
    # message file Path
    Label(AES_encrpt_input, text="Message file path",width=15,height=2, 
          font=('content/entury 20 bold',12),bg= '#222b45',fg=('white')).place(x = 10 , y =150)
    global messagePath_text
    messagePath_text = Text(AES_encrpt_input,width=50,height=3)
    messagePath_text.place(x = 180 , y = 150)
    message_path_button = Button(AES_encrpt_input, text="...", width=2,height=2 ,
                                font=('Century 20 bold',5),bg=('lightgray'), 
                                fg=('white'),command=AES_upload_message_file).place(x = 150 , y = 160)
    
    # Key
    Label(AES_encrpt_input, text="Key",width=15,height=2, 
          font=('content/entury 20 bold',12),bg= '#222b45',fg=('white')).place(x = 10 , y =220)
    global key_text_field
    key_text_field= Text(AES_encrpt_input,width=50,height=3)
    key_text_field.place(x = 180 , y = 220)
    
    
    
    # Next Button
    btn2=Button(AES_encrpt_input, text="Next", width=15, height=2 ,font=10,bg=("#51B5D4",), 
            fg=('white'),command=AES_encrpt_output_screen).place(x = 230 , y = 290)
    
    AES_encrpt_input.mainloop()
    
#---------------------------------------------------------------------------------------------------------------
def destroy_AES_encrpt_output_screen():
    AES_encrpt_output.destroy()
    Home_screen()
    
    
#----------------------------------------------------------------------------------------------------------------

def destroy_AES_decrpt_output_screen():
    AES_decrypt_ouput.destroy()
    Home_screen()
    
#----------------------------------------------------------------------------------------------------------------

def AES_encrpt_output_screen() :
    
    AES_encrypt_submit()
    
    AES_encrpt_input.destroy()
    global AES_encrpt_output
    AES_encrpt_output= Tk()
    AES_encrpt_output.title("Security Project")
    AES_encrpt_output.configure(background = '#222b45')
    screen_width = AES_encrpt_output.winfo_screenwidth()
    screen_height = AES_encrpt_output.winfo_screenheight()
    
    position_top = int(screen_height/2 - window_height/2)
    position_right = int(screen_width/2 - window_width/2)
    
    AES_encrpt_output.geometry(f'{window_width}x{window_height}+{position_right}+{position_top}')
    
    # call AES Encrypt
    key_test_byts = key_test.encode("utf-8")
    encryptedImgPath = AES_encrypt_and_encode(imageFileName[:-1], textFileName[:-1], key_test_byts[:-1])
    
    print(encryptedImgPath)
    
    Label(AES_encrpt_output, text="AES encrpt output",width=15,height=2, 
          font=('content/entury 20 bold',15),bg= '#222b45', fg=('white')).place(x = 200 , y = 20)
    
    # Encrypted Image Path
    Label(AES_encrpt_output, text="Encrypted Image Path",width=30,height=2, 
          font=('content/entury 20 bold',12),bg= '#222b45', fg=('white')).place(x = 30 , y = 80)
    global Encrpted_Image_path
    Encrpted_Image_path = Text(AES_encrpt_output,width=50,height=3)
    Encrpted_Image_path.place(x = 50 , y = 150)
    Encrpted_Image_path.insert(END, encryptedImgPath)
    
    # Home Button
    btn2=Button(AES_encrpt_output, text="Home", width=15, height=2 ,font=10,bg=("#51B5D4"), 
            fg=('white'),command=destroy_AES_encrpt_output_screen).place(x = 230 , y = 290)
    
    AES_encrpt_output.mainloop()
    
#--------------------------------------------------------------------------------------------------------------

def AES_decrypt_input_screen():
    win1.destroy()
    global AES_decrypt_input
    AES_decrypt_input = Tk()
    AES_decrypt_input.title("Security Project")
    AES_decrypt_input.configure(background = '#222b45')
    screen_width = AES_decrypt_input.winfo_screenwidth()
    screen_height = AES_decrypt_input.winfo_screenheight()
    
    position_top = int(screen_height/2 - window_height/2)
    position_right = int(screen_width/2 - window_width/2)
    
    AES_decrypt_input.geometry(f'{window_width}x{window_height}+{position_right}+{position_top}')
    
    Label(AES_decrypt_input, text='AES Decrypt Input',width=15,height=2, 
          font=('content/entury 20 bold',15),bg= '#222b45', fg=('white')).place(x = 200 , y = 20)
    
    # Encrypt Image Path
    Label(AES_decrypt_input, text='Encrypted image path',width=15,height=2, 
          font=('content/entury 20 bold',10),bg= '#222b45', fg=('white')).place(x = 10 , y = 80)
    global original_image_path
    original_image_path = Text(AES_decrypt_input,width=50,height=3)
    original_image_path.place(x = 180 , y = 80)
    image_path_button = Button(AES_decrypt_input, text="...", width=2,height=2 ,
                                font=('Century 20 bold',5),bg=('lightgray'), 
                                fg=('white'),command=AES_Get_encrypt_ImagePath).place(x = 150 , y = 90)
    
    # Restored file Path
    Label(AES_decrypt_input, text='Restored file path',width=15,height=2, 
          font=('content/entury 20 bold',10),bg= '#222b45', fg=('white')).place(x = 10 , y =150)
    global messagePath_text
    messagePath_text = Text(AES_decrypt_input,width=50,height=3)
    messagePath_text.place(x = 180 , y = 150)
    message_path_button = Button(AES_decrypt_input, text="...", width=2,height=2 ,
                                font=('Century 20 bold',5),bg=('lightgray'), 
                                fg=('white'),command=AES_upload_restored_file).place(x = 150 , y = 160)
    
    # Key
    Label(AES_decrypt_input, text='Key',width=15,height=2, 
          font=('content/entury 20 bold',10),bg= '#222b45', fg=('white')).place(x = 10 , y =220)
    global key_text_field
    key_text_field= Text(AES_decrypt_input,width=50,height=3)
    key_text_field.place(x = 180 , y = 220)
    
    
    # Next Button
    btn2=Button(AES_decrypt_input, text="Next", width=15, height=2 ,font=10,bg=("#51B5D4"), 
            fg=('white'),command=AES_decrypt_ouput_screen).place(x = 230 , y = 290)
    
    AES_decrypt_input.mainloop()
    
    
#-------------------------------------------------------------------------------------------------------------

def AES_decrypt_ouput_screen():
    
    AES_encrypt_submit()
    
    AES_decrypt_input.destroy()
    global AES_decrypt_ouput
    AES_decrypt_ouput =Tk()
    AES_decrypt_ouput.title("Security Project")
    AES_decrypt_ouput.configure(background = '#222b45')
    screen_width = AES_decrypt_ouput.winfo_screenwidth()
    screen_height = AES_decrypt_ouput.winfo_screenheight()
    
    position_top = int(screen_height/2 - window_height/2)
    position_right = int(screen_width/2 - window_width/2)
    
    AES_decrypt_ouput.geometry(f'{window_width}x{window_height}+{position_right}+{position_top}')
    
    L=Label (AES_decrypt_ouput, text='AES Decrypt Output',font=(60),bg= '#222b45', fg=('white'))
    L.pack(pady=40)
    Message=Label(AES_decrypt_ouput, text='Message',font=(60),bg= '#222b45', fg=('white')).place(x=20,y=100)
    
    # call AES Decrypt
    key_test_byts = key_test.encode("utf-8")
    origianMessage = AES_decode_and_decrypt(imageFileName[:-1], textFileName[:-1], key_test_byts[:-1])
    print( origianMessage)
    #output = Text(win3,width=50,height=9).place(x=70,y=150)
    original_Message_text = scrolledtext.ScrolledText(AES_decrypt_ouput,wrap=WORD,width=60,height=9)
    original_Message_text.place(x=70,y=140) 
    original_Message_text.insert(INSERT, origianMessage)
    
    
    # Home Button
    btn2=Button(AES_decrypt_ouput, text="Home", width=15, height=2 ,font=10,bg=("#51B5D4"), 
            fg=('white'),command=destroy_AES_decrpt_output_screen).place(x = 230 , y = 290)

#--------------------------------------------------------------------------------------------------------------
#--------------------------------------------------------------------------------------------------------------
#--------------------------------------------------------------------------------------------------------------
##########
# RSA UI #
##########


def RSA_upload_image_file():
    filename = askopenfilename()
    global original_image_path
    original_image_path=Text(RSA_encrpt_input,width=50,height=3)
    original_image_path.place(x = 180 , y = 80)
    original_image_path.insert(END, filename)
    
    
def RSA_upload_message_file():
    filename = askopenfilename()
    global messagePath_text
    messagePath_text=Text(RSA_encrpt_input,width=50,height=3)
    messagePath_text.place(x = 180 , y = 150)
    messagePath_text.insert(END, filename)
    
def RSA_upload_encrypted_file():
    filename = askopenfilename()
    global messagePath_text
    messagePath_text=Text(RSA_decrypt_input,width=50,height=3)
    messagePath_text.place(x = 180 , y = 150)
    messagePath_text.insert(INSERT, filename)
    
    
def RSA_Get_encrypted_ImagePath():
    filename = askopenfilename()
    global original_image_path
    original_image_path=Text(RSA_decrypt_input,width=50,height=3)
    original_image_path.place(x = 180 , y = 80)
    original_image_path.insert(INSERT, filename) 
    

def RSA_upload_public_key():
    filename = askopenfilename()
    global key_text_field
    key_text_field=Text(RSA_encrpt_input,width=50,height=3)
    key_text_field.place(x = 180 , y = 220)
    key_text_field.insert(INSERT, filename)
    
def RSA_upload_private_key():
    filename = askopenfilename()
    global key_text_field
    key_text_field=Text(RSA_decrypt_input,width=50,height=3)
    key_text_field.place(x = 180 , y = 220)
    key_text_field.insert(INSERT, filename)


#----------------------------------------------------------------------------------------------------------------

def RSA_encrpt_input_screen() :
    win2.destroy()
    global RSA_encrpt_input
    RSA_encrpt_input = Tk()
    RSA_encrpt_input.title("Security Project")
    RSA_encrpt_input.configure(background = '#222b45')
    screen_width = RSA_encrpt_input.winfo_screenwidth()
    screen_height = RSA_encrpt_input.winfo_screenheight()
    
    position_top = int(screen_height/2 - window_height/2)
    position_right = int(screen_width/2 - window_width/2)
    
    RSA_encrpt_input.geometry(f'{window_width}x{window_height}+{position_right}+{position_top}')
    
    Label(RSA_encrpt_input, text="RSA encrpt input",width=15,height=2, 
          font=('content/entury 20 bold',15),bg= '#222b45', fg=('white')).place(x = 200 , y = 20)
    
    
    # Image Path
    Label(RSA_encrpt_input, text="Image path",width=15,height=2, 
          font=('content/entury 20 bold',12),bg= '#222b45', fg=('white')).place(x = 10 , y = 80)
    
    global original_image_path
    original_image_path = Text(RSA_encrpt_input,width=50,height=3)
    original_image_path.place(x = 180 , y = 80)
    image_path_button = Button(RSA_encrpt_input, text="...", width=2,height=2 ,
                                font=('Century 20 bold',5),bg=('lightgray'), 
                                fg=('white'),command=RSA_upload_image_file).place(x = 150 , y = 90)
    
    # message file Path
    Label(RSA_encrpt_input, text="Message file path",width=15,height=2, 
          font=('content/entury 20 bold',12),bg= '#222b45', fg=('white')).place(x = 10 , y =150)
    global messagePath_text
    messagePath_text = Text(RSA_encrpt_input,width=50,height=3)
    messagePath_text.place(x = 180 , y = 150)
    message_path_button = Button(RSA_encrpt_input, text="...", width=2,height=2 ,
                                font=('Century 20 bold',5),bg=('lightgray'), 
                                fg=('white'),command=RSA_upload_message_file).place(x = 150 , y = 160)
    
    # public key Path
    Label(RSA_encrpt_input, text="Public key path",width=15,height=2, 
          font=('content/entury 20 bold',12),bg= '#222b45', fg=('white')).place(x = 10 , y =220)
    global key_text_field
    key_text_field = Text(RSA_encrpt_input,width=50,height=3)
    key_text_field.place(x = 180 , y = 220)
    message_path_button = Button(RSA_encrpt_input, text="...", width=2,height=2 ,
                                font=('Century 20 bold',5),bg=('lightgray'), 
                                fg=('white'),command=RSA_upload_public_key).place(x = 150 , y = 230)
    
    
    # Next Button
    btn2=Button(RSA_encrpt_input, text="Next", width=15, height=2 ,font=10,bg=("#51B5D4"), 
            fg=('white'),command=RSA_encrpt_output_screen).place(x = 230 , y = 290)
    
    RSA_encrpt_input.mainloop()
    
#-----------------------------------------------------------------------------------------------------------------

def RSA_decrypt_input_screen():
    win2.destroy()
    global RSA_decrypt_input  
    RSA_decrypt_input =Tk()
    RSA_decrypt_input.title("Security Project")
    RSA_decrypt_input.configure(background = '#222b45')
    screen_width = RSA_decrypt_input.winfo_screenwidth()
    screen_height = RSA_decrypt_input.winfo_screenheight()
    
    position_top = int(screen_height/2 - window_height/2)
    position_right = int(screen_width/2 - window_width/2)
    
    RSA_decrypt_input.geometry(f'{window_width}x{window_height}+{position_right}+{position_top}')
    
    L2 =Label (RSA_decrypt_input, text='RSA Decrypt Input',width=15,height=2, 
          font=('content/entury 20 bold',15),bg= '#222b45', fg=('white')).place(x = 200 , y = 20)
    L3 =Label (RSA_decrypt_input, text='Encrypted image path',width=15,height=2, 
          font=('content/entury 20 bold',10),bg= '#222b45', fg=('white')).place(x = 10 , y = 80)
    L4 =Label (RSA_decrypt_input, text='Restored file path',width=15,height=2, 
          font=('content/entury 20 bold',10),bg= '#222b45', fg=('white')).place(x = 10 , y =150)
    
    # encrypted image
    global original_image_path
    original_image_path = Text(RSA_decrypt_input,width=50,height=3)
    original_image_path.place(x = 180 , y = 80)
    key_button = Button(RSA_decrypt_input, text="...",  width=2,height=2 ,
                                font=('Century 20 bold',5),bg=('lightgray'), 
                                fg=('white'),command=RSA_Get_encrypted_ImagePath).place(x = 150 , y = 90)
    # restord file
    global messagePath_text
    messagePath_text = Text(RSA_decrypt_input,width=50,height=3)
    messagePath_text.place(x = 180 , y = 150)
    key_button = Button(RSA_decrypt_input, text="...", width=2,height=2 ,
                                font=('Century 20 bold',5),bg=('lightgray'), 
                                fg=('white'),command=RSA_upload_encrypted_file).place(x = 150 , y = 160)
    
    # private key Path
    Label(RSA_decrypt_input, text="Private key path",width=15,height=2, 
          font=('content/entury 20 bold',12),bg= '#222b45', fg=('white')).place(x = 10 , y =220)
    global key_text_field
    key_text_field = Text(RSA_decrypt_input,width=50,height=3)
    key_text_field.place(x = 180 , y = 220)
    message_path_button = Button(RSA_decrypt_input, text="...", width=2,height=2 ,
                                font=('Century 20 bold',5),bg=('lightgray'), 
                                fg=('white'),command=RSA_upload_private_key).place(x = 150 , y = 230)
    
    Next = Button (RSA_decrypt_input,text="Next", width=15, height=2 ,font=10,bg=("#51B5D4"), 
            fg=('white'),command=RSA_decrypt_ouput_screen).place(x = 230 , y = 290)
    RSA_decrypt_input.mainloop()
    
#----------------------------------------------------------------------------------------------------------------------------


def RSA_encrpt_output_screen() :
    
    AES_encrypt_submit()
    
    RSA_encrpt_input.destroy()
    global RSA_encrpt_output
    RSA_encrpt_output= Tk()
    RSA_encrpt_output.title("Security Project")
    RSA_encrpt_output.configure(background = '#222b45')
    screen_width = RSA_encrpt_output.winfo_screenwidth()
    screen_height = RSA_encrpt_output.winfo_screenheight()
    
    position_top = int(screen_height/2 - window_height/2)
    position_right = int(screen_width/2 - window_width/2)
    
    RSA_encrpt_output.geometry(f'{window_width}x{window_height}+{position_right}+{position_top}')
      
    encryptedImgPath = RSA_encrypt_and_encode(imageFileName[:-1], textFileName[:-1],key_test[:-1])
       
    Label(RSA_encrpt_output, text="RSA encrpt output",width=15,height=2, 
          font=('content/entury 20 bold',15),bg= '#222b45', fg=('white')).place(x = 200 , y = 20)
    
    # Encrypted Image Path
    Label(RSA_encrpt_output, text="Encrypted Image Path",width=30,height=2, 
          font=('content/entury 20 bold',12),bg= '#222b45', fg=('white')).place(x = 30 , y = 80)
    global Encrpted_Image_path
    Encrpted_Image_path = Text(RSA_encrpt_output,width=50,height=3)
    Encrpted_Image_path.place(x = 50 , y = 150)
    Encrpted_Image_path.insert(INSERT, encryptedImgPath)
    
    # Home Button
    btn2=Button(RSA_encrpt_output, text="Home", width=15, height=2 ,font=10,bg=("#51B5D4"), fg=('white'), 
            command=destroy_RSA_encrpt_output_screen).place(x = 230 , y = 290)
    
    RSA_encrpt_output.mainloop()
#--------------------------------------------------------------------------------------------------------------------

def RSA_decrypt_ouput_screen():
    
    AES_encrypt_submit()
    
    RSA_decrypt_input.destroy()
    global RSA_decrypt_ouput
    RSA_decrypt_ouput =Tk()
    RSA_decrypt_ouput.title("Security Project")
    RSA_decrypt_ouput.configure(background = '#222b45')
    screen_width = RSA_decrypt_ouput.winfo_screenwidth()
    screen_height = RSA_decrypt_ouput.winfo_screenheight()
    
    position_top = int(screen_height/2 - window_height/2)
    position_right = int(screen_width/2 - window_width/2)
    
    RSA_decrypt_ouput.geometry(f'{window_width}x{window_height}+{position_right}+{position_top}')
    
    origianMessage = RSA_decode_and_decrypt(imageFileName[:-1], textFileName[:-1], key_test[:-1])
    
    L=Label (RSA_decrypt_ouput, text='RSA Decrypt Output',font=(60),bg= '#222b45', fg=('white'))
    L.pack(pady=40)
    Message=Label(RSA_decrypt_ouput, text='Message',font=(60),bg= '#222b45', fg=('white')).place(x=20,y=100)
    #output = Text(win3,width=50,height=9).place(x=70,y=150)
    output_Message = scrolledtext.ScrolledText(RSA_decrypt_ouput,wrap=WORD,width=60,height=9)  
    output_Message.place(x=70,y=140)
    output_Message.insert(INSERT,origianMessage)
    home = Button (RSA_decrypt_ouput, text="Home", width=15, height=2 ,
                   font=10,bg=("#51B5D4"), fg=('white'),
                   command=destroy_RSA_decrypt_output_screen).place(x=240,y=310)
    
    RSA_decrypt_ouput.mainloop()
    
#------------------------------------------------------------------------------------------------------------
def destroy_RSA_encrpt_output_screen():
    RSA_encrpt_output.destroy()
    Home_screen()

def destroy_RSA_decrypt_output_screen():
    RSA_decrypt_ouput.destroy()
    Home_screen()
    


    
Home_screen()
